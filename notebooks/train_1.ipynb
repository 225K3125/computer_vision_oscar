# %%
import sys
print(sys.executable)
# Out:
# /home/oscar/documents/university/computer_vision/computer_vision_oscar/.venv/bin/python

# %% [markdown]
# Se hace una matriz de 7 * 7
# 4 4 4 2 5 0 1
# 0 1 6 6 2 0 3
# 7 7 7 7 7 7 7
# 0 1 2 3 2 0 3
# 7 0 0 0 7 7 7
# 0 1 6 6 2 0 3
# 7 7 3 3 7 7 7
#
# 0 = 0 +1 = 1
# 1 = 1.5 + 1 = 2
# 2 = 3 + 1 = 4
# 3 = 5
# 4 = 7
# 5 = 7
# 6 = 7
# 7 = 7

# %%
#Hacer una matriz de 7x7 en 3 bit, alfa 1.5 beta 1
