# %% [markdown]
# <a href="https://colab.research.google.com/github/225K3125/computer_vision_oscar/blob/main/notebooks/train_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
print(sys.executable)
print(f"Versión: {sys.version}")
# Out:
# /usr/bin/python3
# Versión: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
